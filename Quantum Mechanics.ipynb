# %% [markdown]
# # The uncertainty principle

# %%
# Import the necessary modules
import numpy as np
from scipy.optimize import minimize

# Define the position and momentum of a particle
x = 1e-10  # m
p = 1e-20  # kg m/s

# Define the uncertainty in the position and momentum
delta_x = 1e-12  # m
delta_p = 1e-22  # kg m/s

# Compute the uncertainty in the position and momentum using the Heisenberg uncertainty principle
def uncertainty(x, p, delta_x, delta_p):
    # Compute the uncertainty in the position and momentum
    delta_x_p = np.sqrt(delta_x**2 * delta_p**2)

    # Return the uncertainty in the position and momentum
    return delta_x_p

# Solve for the minimum uncertainty using the Heisenberg uncertainty principle
delta_x_p_min = minimize(uncertainty, (x, p), args=(delta_x, delta_p))

# Print the minimum uncertainty
print(f'delta_x_p_min = {delta_x_p_min.fun:.3e}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 22
#      19     return delta_x_p
#      21 # Solve for the minimum uncertainty using the Heisenberg uncertainty principle
# ---> 22 delta_x_p_min = minimize(uncertainty, (x, p), args=(delta_x, delta_p))
#      24 # Print the minimum uncertainty
#      25 print(f'delta_x_p_min = {delta_x_p_min.fun:.3e}')
#
# File ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/scipy/optimize/_minimize.py:694, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     692     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     693 elif meth == 'bfgs':
# --> 694     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     695 elif meth == 'newton-cg':
#     696     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
# ...

# %% [markdown]
# # Wave-particle duality

# %%
# Import the necessary modules
import numpy as np
from scipy.integrate import solve_ivp
from matplotlib import pyplot as plt

# Define the wave function of a particle
def wave_function(x, t):
    # Compute the wave function of the particle
    psi = np.sin(x - t)

    # Return the wave function of the particle
    return psi

# Compute the probability density of the particle using the wave function
def probability_density(x, t):
    # Compute the probability density of the particle
    rho = wave_function(x, t)**2

    # Return the probability density of the particle
    return rho

# Solve for the time evolution of the wave function using the Schrödinger equation
x = np.linspace(0, 2 * np.pi, 100)
t = np.linspace(0, 10, 100)
psi_t = solve_ivp(wave_function, (0, 10), x, t_eval=t)

# Compute the probability density of the particle at each time
rho_t = probability_density(psi_t.y, t)

# Plot the probability density of the particle over time
plt.plot(t, rho_t)
plt.xlabel('Time (s)')
plt.ylabel('Probability Density')
plt.show()

# %% [markdown]
# # Quantum entanglement

# %%
# Import the necessary modules
import numpy as np
from scipy.linalg import expm

# Define the quantum state of two entangled particles
psi = np.array([[1], [0], [0], [0]])

# Define the Pauli matrices
sigma_x = np.array([[0, 1], [1, 0]])
sigma_y = np.array([[0, -1j], [1j, 0]])
sigma_z = np.array([[1, 0], [0, -1]])

# Define the measurement operator for the first particle
M_1 = np.kron(sigma_z, np.identity(2))

# Define the measurement operator for the second particle
M_2 = np.kron(np.identity(2), sigma_z)

# Compute the measurement probabilities of the two particles
P_1 = np.real(psi.conj().T @ M_1 @ psi)
P_2 = np.real(psi.conj().T @ M_2 @ psi)

# Print the measurement probabilities of the two particles
print(f'P_1 = {P_1:.3f}, P_2 = {P_2:.3f}')

# Compute the measurement operator for the two particles
M = M_1 + M_2

# Compute the state of the two particles after the measurement
psi_measured = M @ psi

# Print the state of the two particles after the measurement
print(f'psi_measured = {psi_measured.T}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 24
#      21 P_2 = np.real(psi.conj().T @ M_2 @ psi)
#      23 # Print the measurement probabilities of the two particles
# ---> 24 print(f'P_1 = {P_1:.3f}, P_2 = {P_2:.3f}')
#      26 # Compute the measurement operator for the two particles
#      27 M = M_1 + M_2
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %% [markdown]
# # Quantum tunneling

# %%
# Import the necessary modules
import numpy as np
from scipy.integrate import solve_ivp

# Define the potential energy of the particle
def potential(x):
    # Compute the potential energy of the particle
    V = np.heaviside(x, 0.5) * (x**2 - 1)

    # Return the potential energy of the particle
    return V

# Define the Schrödinger equation for the particle
def schrodinger(t, psi):
    # Define the kinetic energy of the particle
    T = -1 / 2 * psi.diff(x, 2)

    # Define the potential energy of the particle
    V = potential(x) * psi

    # Compute the Schrödinger equation for the particle
    dpsi_dt = 1j * (T + V)

    # Return the Schrödinger equation for the particle
    return dpsi_dt

# Define the grid of positions and times
x = np.linspace(-2, 2, 100)
t = np.linspace(0, 10, 100)

# Define the initial state of the particle
psi_0 = np.exp(-x**2)

# Solve the Schrödinger equation for the particle
psi_t = solve_ivp(schrodinger, (0, 10), psi_0, t_eval=t)

# Compute the probability density of the particle at each time
rho_t = np.abs(psi_t.y)**2

# Plot the probability density of the particle over time
plt.plot(x, rho_t.T)
plt.xlabel('Position (m)')
plt.ylabel('Probability Density')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 35
#      32 psi_0 = np.exp(-x**2)
#      34 # Solve the Schrödinger equation for the particle
# ---> 35 psi_t = solve_ivp(schrodinger, (0, 10), psi_0, t_eval=t)
#      37 # Compute the probability density of the particle at each time
#      38 rho_t = np.abs(psi_t.y)**2
#
# File ~/.pyenv/versions/miniforge3/lib/python3.9/site-packages/scipy/integrate/_ivp/ivp.py:555, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     552 if method in METHODS:
#     553     method = METHODS[method]
# --> 555 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     557 if t_eval is None:
#     558     ts = [t0]
#
# ...

# %% [markdown]
# # Quantum superposition

# %%
# Import the necessary modules
import numpy as np
from scipy.linalg import expm

# Define the quantum state of the particle
psi_0 = 1 / np.sqrt(2) * np.array([[1], [1]])

# Define the measurement operator for the particle
M = np.array([[1, 0], [0, -1]])

# Compute the state of the particle after the measurement
psi_measured = M @ psi_0

# Print the state of the particle after the measurement
print(f'psi_measured = {psi_measured.T}')
# Out:
# psi_measured = [[ 0.70710678 -0.70710678]]
